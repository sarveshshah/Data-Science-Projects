# %% [markdown]
# ## Inserting data in MySQL using Python
#
# First let's start with a basic piece of code that fetches the data that we want to insert in the database. For our example, we will get the data about the Citibike stations [https://data.cityofnewyork.us/NYC-BigApps/Citi-Bike-Live-Station-Feed-JSON-/p94q-8hxh](https://data.cityofnewyork.us/NYC-BigApps/Citi-Bike-Live-Station-Feed-JSON-/p94q-8hxh), using the correspoding API call provided by the Citibike [website](https://www.citibikenyc.com/system-data):

# %%
import requests
import json

# %%
# Let's get the data from the Citibike API
url = 'http://www.citibikenyc.com/stations/json'
resp = requests.get(url)

# %%
# We transform the returned JSON answer from the API into a Python dictionary object
results = json.loads(resp.text)

# %%
# We only need a subset of the data in the JSON returned by the Citibike API, so we keep only we need
data = results["stationBeanList"]

# %%
len(data)
# Out:
# 814

# %%
#print an example
print(data[0])
# Out:
# {'id': 281, 'stationName': 'Grand Army Plaza & Central Park S', 'availableDocks': 36, 'totalDocks': 57, 'latitude': 40.7643971, 'longitude': -73.97371465, 'statusValue': 'In Service', 'statusKey': 1, 'availableBikes': 18, 'stAddress1': 'Grand Army Plaza & Central Park S', 'stAddress2': '', 'city': '', 'postalCode': '', 'location': '', 'altitude': '', 'testStation': False, 'lastCommunicationTime': '2018-11-15 04:35:46 PM', 'landMark': ''}

# %% [markdown]
# Now we will connect to our MySQL server. We will use the `pymysql` library of Python.
#
# If you do not have the library, you need to install it by typing in the shell:
#
# `conda install pymysql`

# %%
import pymysql
import sys

connection = pymysql.connect(host = 'localhost',
                             user = 'root',
                             passwd = '',
                             charset='utf8', use_unicode=True);

# %% [markdown]
# Once we have connected successfully, we need to create our database:

# %%
# Query to create a database
db_name = 'citibike'
create_db_query = "CREATE DATABASE IF NOT EXISTS {0} DEFAULT CHARACTER SET 'utf8'".format(db_name)

# Create a database
cursor = connection.cursor()
cursor.execute(create_db_query)
cursor.close()

# %% [markdown]
# Then we create the table where we will store our data. For our example, we will just import three fields in the database: station_id, station_name, and number_of_docks

# %%
cursor = connection.cursor()
db_name = 'citibike'
table_name = 'Docks'
# Create a table
# The {0} and {1} are placeholders for the parameters in the format(....) statement
create_table_query = '''CREATE TABLE IF NOT EXISTS {0}.{1} 
                                (station_id int, 
                                station_name varchar(250), 
                                number_of_docks int,
                                available_docks int,
                                date datetime,
                                PRIMARY KEY(station_id, date)
                                )'''.format(db_name, table_name)
cursor.execute(create_table_query)
cursor.close()

# %% [markdown]
# Finally, we import the data into our table, using the INSERT command.

# %%
from datetime import date, datetime, timedelta

query_template = '''
INSERT INTO 
citibike.Docks(station_id, station_name,
                number_of_docks, available_docks, date) 
        VALUES (%s, %s, %s, %s, %s)'''

cursor = connection.cursor()

for entry in data:
    dockid = entry["id"]
    addr = entry["stationName"]
    docks = entry["totalDocks"]
    available = entry["availableDocks"]
    # date =  datetime.now()
    # lastcommunicationtime is a string of 
    # the form "2016-02-09 10:16:49 AM"
    # See https://docs.python.org/3.6/library/datetime.html#strftime-and-strptime-behavior
    # to see the documentation on how to parse 
    date = datetime.strptime(entry["lastCommunicationTime"], 
                             '%Y-%m-%d %I:%M:%S %p')
    print("Inserting station", dockid, "at", addr)
    query_parameters = (dockid, addr, docks, available, date)
    cursor.execute(query_template, query_parameters)

'''
Commit changes to stable storage
'''
connection.commit()
cursor.close()
# Out:
# Inserting station 281 at Grand Army Plaza & Central Park S
# Inserting station 304 at Broadway & Battery Pl
# Inserting station 377 at 6 Ave & Canal St
# Inserting station 402 at Broadway & E 22 St
# Inserting station 491 at E 24 St & Park Ave S
# Inserting station 514 at 12 Ave & W 40 St
# Inserting station 520 at W 52 St & 5 Ave
# Inserting station 3236 at W 42 St & Dyer Ave
# Inserting station 3255 at 8 Ave & W 31 St
# Inserting station 3443 at W 52 St & 6 Ave
# Inserting station 72 at W 52 St & 11 Ave
# Inserting station 79 at Franklin St & W Broadway
# Inserting station 82 at St James Pl & Pearl St
# Inserting station 83 at Atlantic Ave & Fort Greene Pl
# Inserting station 119 at Park Ave & St Edwards St
# Inserting station 120 at Lexington Ave & Classon Ave
# Inserting station 127 at Barrow St & Hudson St
# Inserting station 128 at MacDougal St & Prince St
# Inserting station 143 at Clinton St & Joralemon St
# Inserting station 144 at Nassau St & Navy St
# Inserting station 146 at Hudson St & Reade St
# Inserting station 150 at E 2 St & Avenue C
# Inserting station 151 at Cleveland Pl & Spring St
# Inserting station 157 at Henry St & Atlantic Ave
# Inserting station 161 at LaGuardia Pl & W 3 St
# Inserting station 164 at E 47 St & 2 Ave
# Inserting station 167 at E 39 St & 3 Ave
# Inserting station 168 at W 18 St & 6 Ave
# Inserting station 173 at Broadway & W 49 St
# Inserting station 174 at E 25 St & 1 Ave
# Inserting station 195 at Liberty St & Broadway
# Inserting station 212 at W 16 St & The High Line
# Inserting station 216 at Columbia Heights & Cranberry St
# Inserting station 217 at Old Fulton St
# Inserting station 223 at W 13 St & 7 Ave
# Inserting station 228 at E 48 St & 3 Ave
# Inserting station 229 at Great Jones St
# Inserting station 232 at Cadman Plaza E & Tillary St
# Inserting station 236 at St Marks Pl & 2 Ave
# Inserting station 237 at E 11 St & 2 Ave
# Inserting station 238 at Bank St & Washington St
# Inserting station 239 at Willoughby St & Fleet St
# Inserting station 241 at DeKalb Ave & S Portland Ave
# Inserting station 242 at Carlton Ave & Flushing Ave
# Inserting station 243 at Fulton St & Rockwell Pl
# Inserting station 244 at Willoughby Ave & Hall St
# Inserting station 245 at Myrtle Ave & St Edwards St
# Inserting station 247 at Perry St & Bleecker St
# Inserting station 248 at Laight St & Hudson St
# Inserting station 249 at Harrison St & Hudson St
# Inserting station 251 at Mott St & Prince St
# Inserting station 252 at MacDougal St & Washington Sq
# Inserting station 254 at W 11 St & 6 Ave
# Inserting station 257 at Lispenard St & Broadway
# Inserting station 258 at DeKalb Ave & Vanderbilt Ave
# Inserting station 259 at South St & Whitehall St
# Inserting station 260 at Broad St & Bridge St
# Inserting station 261 at Johnson St & Gold St
# Inserting station 262 at Washington Park
# Inserting station 264 at Maiden Ln & Pearl St
# Inserting station 265 at Stanton St & Chrystie St
# Inserting station 266 at Avenue D & E 8 St
# Inserting station 267 at Broadway & W 36 St
# Inserting station 268 at Howard St & Centre St
# Inserting station 270 at Adelphi St & Myrtle Ave
# Inserting station 274 at Lafayette Ave & Fort Greene Pl
# Inserting station 275 at Washington Ave & Greene Ave
# Inserting station 276 at Duane St & Greenwich St
# Inserting station 278 at Concord St & Bridge St
# Inserting station 279 at Peck Slip & Front St
# Inserting station 280 at E 10 St & 5 Ave
# Inserting station 282 at Kent Ave & S 11 St
# Inserting station 285 at Broadway & E 14 St
# Inserting station 289 at Monroe St & Classon Ave
# Inserting station 291 at Madison St & Montgomery St
# Inserting station 293 at Lafayette St & E 8 St
# Inserting station 295 at Pike St & E Broadway
# Inserting station 296 at Division St & Bowery
# Inserting station 297 at E 15 St & 3 Ave
# Inserting station 298 at 3 Ave & Schermerhorn St
# Inserting station 301 at E 2 St & Avenue B
# Inserting station 302 at Avenue D & E 3 St
# Inserting station 303 at Mercer St & Spring St
# Inserting station 305 at E 58 St & 3 Ave
# Inserting station 307 at Canal St & Rutgers St
# Inserting station 308 at St James Pl & Oliver St
# Inserting station 309 at Murray St & West St
# Inserting station 310 at State St & Smith St
# Inserting station 311 at Norfolk St & Broome St
# Inserting station 312 at Allen St & Stanton St
# Inserting station 313 at Washington Ave & Park Ave
# Inserting station 314 at Cadman Plaza West & Montague St
# Inserting station 315 at South St & Gouverneur Ln
# Inserting station 316 at Fulton St & William St
# Inserting station 317 at E 6 St & Avenue B
# Inserting station 319 at Fulton St & Broadway
# Inserting station 320 at Leonard St & Church St
# Inserting station 321 at Cadman Plaza E & Red Cross Pl
# Inserting station 322 at Clinton St & Tillary St
# Inserting station 323 at Lawrence St & Willoughby St
# Inserting station 324 at DeKalb Ave & Hudson Ave
# Inserting station 325 at E 19 St & 3 Ave
# Inserting station 326 at E 11 St & 1 Ave
# Inserting station 327 at Vesey Pl & River Terrace
# Inserting station 328 at Watts St & Greenwich St
# Inserting station 330 at Reade St & Broadway
# Inserting station 331 at Pike St & Monroe St
# Inserting station 332 at Cherry St
# Inserting station 334 at W 20 St & 7 Ave
# Inserting station 335 at Washington Pl & Broadway
# Inserting station 336 at Sullivan St & Washington Sq
# Inserting station 337 at Old Slip & Front St
# Inserting station 339 at Avenue D & E 12 St
# Inserting station 340 at Madison St & Clinton St
# Inserting station 341 at Stanton St & Mangin St
# Inserting station 342 at Columbia St & Rivington St
# Inserting station 343 at Clinton Ave & Flushing Ave
# Inserting station 344 at Monroe St & Bedford Ave
# Inserting station 346 at Bank St & Hudson St
# Inserting station 347 at Greenwich St & W Houston St
# Inserting station 349 at Rivington St & Ridge St
# Inserting station 350 at Clinton St & Grand St
# Inserting station 351 at Front St & Maiden Ln
# Inserting station 353 at S Portland Ave & Hanson Pl
# Inserting station 354 at Emerson Pl & Myrtle Ave
# Inserting station 355 at Bayard St & Baxter St
# Inserting station 356 at Bialystoker Pl & Delancey St
# Inserting station 357 at E 11 St & Broadway
# Inserting station 358 at Christopher St & Greenwich St
# Inserting station 359 at E 47 St & Park Ave
# Inserting station 360 at William St & Pine St
# Inserting station 361 at Allen St & Hester St
# Inserting station 362 at Broadway & W 37 St
# Inserting station 363 at West Thames St
# Inserting station 364 at Lafayette Ave & Classon Ave
# Inserting station 365 at Fulton St & Grand Ave
# Inserting station 366 at Clinton Ave & Myrtle Ave
# Inserting station 368 at Carmine St & 6 Ave
# Inserting station 369 at Washington Pl & 6 Ave
# Inserting station 372 at Franklin Ave & Myrtle Ave
# Inserting station 373 at Willoughby Ave & Walworth St
# Inserting station 376 at John St & William St
# Inserting station 379 at W 31 St & 7 Ave
# Inserting station 380 at W 4 St & 7 Ave S
# Inserting station 382 at University Pl & E 14 St
# Inserting station 383 at Greenwich Ave & Charles St
# Inserting station 385 at E 55 St & 2 Ave
# Inserting station 386 at Centre St & Worth St
# Inserting station 387 at Centre St & Chambers St
# Inserting station 388 at W 26 St & 10 Ave
# Inserting station 389 at Broadway & Berry St
# Inserting station 390 at Duffield St & Willoughby St
# Inserting station 391 at Clark St & Henry St
# Inserting station 392 at Jay St & Tech Pl
# Inserting station 393 at E 5 St & Avenue C
# Inserting station 394 at E 9 St & Avenue C
# Inserting station 396 at Lefferts Pl & Franklin Ave
# Inserting station 397 at Fulton St & Clermont Ave
# Inserting station 398 at Atlantic Ave & Furman St
# Inserting station 399 at Lafayette Ave & St James Pl
# Inserting station 400 at Pitt St & Stanton St
# Inserting station 401 at Allen St & Rivington St
# Inserting station 403 at E 2 St & 2 Ave
# Inserting station 405 at Washington St & Gansevoort St
# Inserting station 406 at Hicks St & Montague St
# Inserting station 407 at Henry St & Poplar St
# Inserting station 408 at Market St & Cherry St
# Inserting station 409 at DeKalb Ave & Skillman St
# Inserting station 410 at Suffolk St & Stanton St
# Inserting station 411 at E 6 St & Avenue D
# Inserting station 412 at Forsyth St & Canal St
# Inserting station 414 at Pearl St & Anchorage Pl
# Inserting station 415 at Pearl St & Hanover Square
# Inserting station 416 at Cumberland St & Lafayette Ave
# Inserting station 417 at Barclay St & Church St
# Inserting station 418 at Front St & Gold St
# Inserting station 419 at Carlton Ave & Park Ave
# Inserting station 420 at Clermont Ave & Lafayette Ave
# Inserting station 421 at Clermont Ave & Park Ave
# Inserting station 422 at W 59 St & 10 Ave
# Inserting station 423 at W 54 St & 9 Ave
# Inserting station 426 at West St & Chambers St
# Inserting station 427 at Bus Slip & State St
# Inserting station 432 at E 7 St & Avenue A
# Inserting station 435 at W 21 St & 6 Ave
# Inserting station 436 at Hancock St & Bedford Ave
# Inserting station 437 at Macon St & Nostrand Ave
# Inserting station 438 at St Marks Pl & 1 Ave
# Inserting station 439 at E 4 St & 2 Ave
# Inserting station 440 at E 45 St & 3 Ave
# Inserting station 441 at E 52 St & 2 Ave
# Inserting station 442 at W 27 St & 7 Ave
# Inserting station 443 at Bedford Ave & S 9 St
# Inserting station 445 at E 10 St & Avenue A
# Inserting station 446 at W 24 St & 7 Ave
# Inserting station 447 at 8 Ave & W 52 St
# Inserting station 448 at W 37 St & 10 Ave
# Inserting station 450 at W 49 St & 8 Ave
# Inserting station 453 at W 22 St & 8 Ave
# Inserting station 454 at E 51 St & 1 Ave
# Inserting station 455 at 1 Ave & E 44 St
# Inserting station 456 at E 53 St & Madison Ave
# Inserting station 457 at Broadway & W 58 St
# Inserting station 458 at 11 Ave & W 27 St
# Inserting station 459 at W 20 St & 11 Ave
# Inserting station 460 at S 4 St & Wythe Ave
# Inserting station 461 at E 20 St & 2 Ave
# Inserting station 462 at W 22 St & 10 Ave
# Inserting station 465 at Broadway & W 41 St
# Inserting station 466 at W 25 St & 6 Ave
# Inserting station 467 at Dean St & 4 Ave
# Inserting station 468 at Broadway & W 56 St
# Inserting station 469 at Broadway & W 53 St
# Inserting station 470 at W 20 St & 8 Ave
# Inserting station 471 at Grand St & Havemeyer St
# Inserting station 472 at E 32 St & Park Ave
# Inserting station 473 at Rivington St & Chrystie St
# Inserting station 474 at 5 Ave & E 29 St
# Inserting station 476 at E 31 St & 3 Ave
# Inserting station 477 at W 41 St & 8 Ave
# Inserting station 478 at 11 Ave & W 41 St
# Inserting station 479 at 9 Ave & W 45 St
# Inserting station 480 at W 53 St & 10 Ave
# Inserting station 481 at S 3 St & Bedford Ave
# Inserting station 482 at W 15 St & 7 Ave
# Inserting station 483 at E 12 St & 3 Ave
# Inserting station 484 at W 44 St & 5 Ave
# Inserting station 485 at W 37 St & 5 Ave
# Inserting station 486 at Broadway & W 29 St
# Inserting station 487 at E 20 St & FDR Drive
# Inserting station 490 at 8 Ave & W 33 St
# Inserting station 492 at W 33 St & 7 Ave
# Inserting station 493 at W 45 St & 6 Ave
# Inserting station 494 at W 26 St & 8 Ave
# Inserting station 495 at W 47 St & 10 Ave
# Inserting station 496 at E 16 St & 5 Ave
# Inserting station 497 at E 17 St & Broadway
# Inserting station 498 at Broadway & W 32 St
# Inserting station 499 at Broadway & W 60 St
# Inserting station 500 at Broadway & W 51 St
# Inserting station 501 at FDR Drive & E 35 St
# Inserting station 502 at Henry St & Grand St
# Inserting station 503 at E 20 St & Park Ave
# Inserting station 504 at 1 Ave & E 16 St
# Inserting station 505 at 6 Ave & W 33 St
# Inserting station 507 at E 25 St & 2 Ave
# Inserting station 508 at W 46 St & 11 Ave
# Inserting station 509 at 9 Ave & W 22 St
# Inserting station 513 at W 56 St & 10 Ave
# Inserting station 515 at W 43 St & 10 Ave
# Inserting station 516 at E 47 St & 1 Ave
# Inserting station 517 at Pershing Square South
# Inserting station 518 at E 39 St & 2 Ave
# Inserting station 519 at Pershing Square North
# Inserting station 522 at E 51 St & Lexington Ave
# Inserting station 523 at W 38 St & 8 Ave
# Inserting station 524 at W 43 St & 6 Ave
# Inserting station 525 at W 34 St & 11 Ave
# Inserting station 526 at E 33 St & 5 Ave
# Inserting station 528 at 2 Ave & E 31 St
# Inserting station 529 at W 42 St & 8 Ave
# Inserting station 530 at 11 Ave & W 59 St
# Inserting station 531 at Forsyth St & Broome St
# Inserting station 532 at S 5 Pl & S 5 St
# Inserting station 533 at Broadway & W 38 St
# Inserting station 534 at Water - Whitehall Plaza
# Inserting station 536 at 1 Ave & E 30 St
# Inserting station 539 at Metropolitan Ave & Bedford Ave
# Inserting station 540 at Lexington Ave & E 29 St
# Inserting station 545 at E 23 St & 1 Ave
# Inserting station 546 at E 30 St & Park Ave S
# Inserting station 2000 at Front St & Washington St
# Inserting station 2001 at Sands St & Navy St
# Inserting station 2002 at Wythe Ave & Metropolitan Ave
# Inserting station 2003 at 1 Ave & E 18 St
# Inserting station 2005 at Railroad Ave & Kay Ave
# Inserting station 2006 at Central Park S & 6 Ave
# Inserting station 2008 at Little West St & 1 Pl
# Inserting station 2009 at Catherine St & Monroe St
# Inserting station 2010 at Grand St & Greene St
# Inserting station 2012 at E 27 St & 1 Ave
# Inserting station 2021 at W 45 St & 8 Ave
# Inserting station 2022 at E 60 St & York Ave
# Inserting station 2023 at E 55 St & Lexington Ave
# Inserting station 3002 at South End Ave & Liberty St
# Inserting station 3016 at Kent Ave & N 7 St
# Inserting station 3041 at Kingston Ave & Herkimer St
# Inserting station 3042 at Fulton St & Utica Ave
# Inserting station 3043 at Lewis Ave & Decatur St
# Inserting station 3044 at Albany Ave & Fulton St
# Inserting station 3046 at Marcus Garvey Blvd & Macon St
# Inserting station 3047 at Halsey St & Tompkins Ave
# Inserting station 3048 at Putnam Ave & Nostrand Ave
# Inserting station 3049 at Cambridge Pl & Gates Ave
# Inserting station 3050 at Putnam Ave & Throop Ave
# Inserting station 3052 at Lewis Ave & Madison St
# Inserting station 3053 at Marcy Ave & Lafayette Ave
# Inserting station 3054 at Greene Ave & Throop Ave
# Inserting station 3055 at Greene Ave & Nostrand Ave
# Inserting station 3056 at Kosciuszko St & Nostrand Ave
# Inserting station 3057 at Kosciuszko St & Tompkins Ave
# Inserting station 3058 at Lewis Ave & Kosciuszko St
# Inserting station 3059 at Pulaski St & Marcus Garvey Blvd
# Inserting station 3060 at Willoughby Ave & Tompkins Ave
# Inserting station 3061 at Throop Ave & Myrtle Ave
# Inserting station 3062 at Myrtle Ave & Marcy Ave
# Inserting station 3063 at Nostrand Ave & Myrtle Ave
# Inserting station 3064 at Myrtle Ave & Lewis Ave
# Inserting station 3065 at Union Ave & Wallabout St
# Inserting station 3066 at Tompkins Ave & Hopkins St
# Inserting station 3067 at Broadway & Whipple St
# Inserting station 3068 at Humboldt St & Varet St
# Inserting station 3069 at Lorimer St & Broadway
# Inserting station 3070 at McKibbin St & Manhattan Ave
# Inserting station 3071 at Boerum St & Broadway
# Inserting station 3072 at Leonard St & Boerum St
# Inserting station 3074 at Montrose Ave & Bushwick Ave
# Inserting station 3075 at Division Ave & Marcy Ave
# Inserting station 3076 at Scholes St & Manhattan Ave
# Inserting station 3077 at Stagg St & Union Ave
# Inserting station 3078 at Broadway & Roebling St
# Inserting station 3080 at S 4 St & Rodney St
# Inserting station 3081 at Graham Ave & Grand St
# Inserting station 3082 at Hope St & Union Ave
# Inserting station 3083 at Bushwick Ave & Powers St
# Inserting station 3085 at Roebling St & N 4 St
# Inserting station 3086 at Graham Ave & Conselyea St
# Inserting station 3087 at Metropolitan Ave & Meeker Ave
# Inserting station 3088 at Union Ave & Jackson St
# Inserting station 3091 at Frost St & Meeker St
# Inserting station 3092 at Berry St & N 8 St
# Inserting station 3093 at N 6 St & Bedford Ave
# Inserting station 3094 at Graham Ave & Withers St
# Inserting station 3095 at Graham Ave & Herbert St
# Inserting station 3096 at Union Ave & N 12 St
# Inserting station 3100 at Nassau Ave & Newell St
# Inserting station 3101 at N 12 St & Bedford Ave
# Inserting station 3102 at Driggs Ave & Lorimer St
# Inserting station 3105 at N 15 St & Wythe Ave
# Inserting station 3106 at Driggs Ave & N Henry St
# Inserting station 3107 at Bedford Ave & Nassau Ave
# Inserting station 3108 at Nassau Ave & Russell St
# Inserting station 3109 at Banker St & Meserole Ave
# Inserting station 3110 at Meserole Ave & Manhattan Ave
# Inserting station 3112 at Milton St & Franklin St
# Inserting station 3113 at Greenpoint Ave & Manhattan Ave
# Inserting station 3115 at India St & Manhattan Ave
# Inserting station 3116 at Huron St & Franklin St
# Inserting station 3117 at Franklin St & Dupont St
# Inserting station 3118 at McGuinness Blvd & Eagle St
# Inserting station 3119 at Vernon Blvd & 50 Ave
# Inserting station 3120 at Center Blvd & Borden Ave
# Inserting station 3121 at Jackson Ave & 46 Rd
# Inserting station 3122 at 48 Ave & 5 St
# Inserting station 3123 at 31 St & Thomson Ave
# Inserting station 3124 at 46 Ave & 5 St
# Inserting station 3125 at 45 Rd & 11 St
# Inserting station 3126 at 44 Dr & Jackson Ave
# Inserting station 3127 at 9 St & 44 Rd
# Inserting station 3128 at 21 St & 43 Ave
# Inserting station 3129 at Queens Plaza North & Crescent St
# Inserting station 3130 at 21 St & Queens Plaza North
# Inserting station 3131 at E 68 St & 3 Ave
# Inserting station 3132 at E 59 St & Madison Ave
# Inserting station 3134 at 3 Ave & E 62 St
# Inserting station 3135 at E 75 St & 3 Ave
# Inserting station 3136 at 5 Ave & E 63 St
# Inserting station 3137 at 5 Ave & E 73 St
# Inserting station 3139 at E 72 St & Park Ave
# Inserting station 3140 at 1 Ave & E 78 St
# Inserting station 3141 at 1 Ave & E 68 St
# Inserting station 3142 at 1 Ave & E 62 St
# Inserting station 3143 at 5 Ave & E 78 St
# Inserting station 3144 at E 81 St & Park Ave
# Inserting station 3145 at E 84 St & Park Ave
# Inserting station 3146 at E 81 St & 3 Ave
# Inserting station 3147 at E 85 St & 3 Ave
# Inserting station 3148 at E 84 St & 1 Ave
# Inserting station 3150 at E 85 St & York Ave
# Inserting station 3151 at E 81 St & York Ave
# Inserting station 3152 at 3 Ave & E 71 St
# Inserting station 3153 at E 71 St & 2 Ave
# Inserting station 3154 at E 77 St & 3 Ave
# Inserting station 3155 at Lexington Ave & E 63 St
# Inserting station 3156 at E 72 St & York Ave
# Inserting station 3157 at East End Ave & E 86 St
# Inserting station 3158 at W 63 St & Broadway
# Inserting station 3159 at W 67 St & Broadway
# Inserting station 3160 at Central Park West & W 76 St
# Inserting station 3161 at W 76 St & Columbus Ave
# Inserting station 3162 at W 78 St & Broadway
# Inserting station 3163 at Central Park West & W 68 St
# Inserting station 3164 at Columbus Ave & W 72 St
# Inserting station 3165 at Central Park West & W 72 St
# Inserting station 3166 at Riverside Dr & W 72 St
# Inserting station 3167 at Amsterdam Ave & W 73 St
# Inserting station 3168 at Central Park West & W 85 St
# Inserting station 3169 at Riverside Dr & W 82 St
# Inserting station 3170 at W 84 St & Columbus Ave
# Inserting station 3171 at Amsterdam Ave & W 82 St
# Inserting station 3172 at W 74 St & Columbus Ave
# Inserting station 3173 at Riverside Blvd & W 67 St
# Inserting station 3175 at W 70 St & Amsterdam Ave
# Inserting station 3177 at W 84 St & Broadway
# Inserting station 3178 at Riverside Dr & W 78 St
# Inserting station 3179 at Park Ave & Marcus Garvey Blvd
# Inserting station 3180 at Brooklyn Bridge Park - Pier 2
# Inserting station 3183 at Exchange Place
# Inserting station 3184 at Paulus Hook
# Inserting station 3185 at City Hall
# Inserting station 3186 at Grove St PATH
# Inserting station 3187 at Warren St
# Inserting station 3191 at Union St
# Inserting station 3192 at Liberty Light Rail
# Inserting station 3193 at Lincoln Park
# Inserting station 3194 at McGinley Square
# Inserting station 3195 at Sip Ave
# Inserting station 3196 at Riverview Park
# Inserting station 3198 at Heights Elevator
# Inserting station 3199 at Newport Pkwy
# Inserting station 3201 at Dey St
# Inserting station 3202 at Newport PATH
# Inserting station 3203 at Hamilton Park
# Inserting station 3205 at JC Medical Center
# Inserting station 3206 at Hilltop
# Inserting station 3207 at Oakland Ave
# Inserting station 3209 at Brunswick St
# Inserting station 3210 at Pershing Field
# Inserting station 3211 at Newark Ave
# Inserting station 3212 at Christ Hospital
# Inserting station 3213 at Van Vorst Park
# Inserting station 3214 at Essex Light Rail
# Inserting station 3220 at 5 Corners Library
# Inserting station 3221 at 47 Ave & 31 St
# Inserting station 3223 at E 55 St & 3 Ave
# Inserting station 3225 at Baldwin at Montgomery
# Inserting station 3226 at W 82 St & Central Park West
# Inserting station 3231 at E 67 St & Park Ave
# Inserting station 3232 at Bond St & Fulton St
# Inserting station 3233 at E 48 St & 5 Ave
# Inserting station 3235 at E 41 St & Madison Ave
# Inserting station 3241 at Monroe St & Tompkins Ave
# Inserting station 3242 at Schermerhorn St & Court St
# Inserting station 3243 at E 58 St & 1 Ave
# Inserting station 3244 at University Pl & E 8 St
# Inserting station 3249 at Verona Pl & Fulton St
# Inserting station 3256 at Pier 40 - Hudson River Park
# Inserting station 3258 at W 27 St & 10 Ave
# Inserting station 3259 at 9 Ave & W 28 St
# Inserting station 3260 at Mercer St & Bleecker St
# Inserting station 3263 at Cooper Square & Astor Pl
# Inserting station 3267 at Morris Canal
# Inserting station 3268 at Lafayette Park
# Inserting station 3269 at Brunswick & 6th
# Inserting station 3270 at Jersey & 6th St
# Inserting station 3272 at Jersey & 3rd
# Inserting station 3273 at Manila & 1st
# Inserting station 3275 at Columbus Drive
# Inserting station 3276 at Marin Light Rail
# Inserting station 3277 at Communipaw & Berry Lane
# Inserting station 3278 at Monmouth and 6th
# Inserting station 3279 at Dixon Mills
# Inserting station 3280 at Astor Place
# Inserting station 3281 at Leonard Gordon Park
# Inserting station 3282 at 5 Ave & E 88 St
# Inserting station 3283 at W 89 St & Columbus Ave
# Inserting station 3284 at E 88 St & Park Ave
# Inserting station 3285 at W 87 St & Amsterdam Ave
# Inserting station 3286 at E 89 St & 3 Ave
# Inserting station 3288 at E 88 St & 1 Ave
# Inserting station 3289 at W 90 St & Amsterdam Ave
# Inserting station 3290 at E 89 St & York Ave
# Inserting station 3292 at 5 Ave & E 93 St
# Inserting station 3293 at W 92 St & Broadway
# Inserting station 3294 at E 91 St & Park Ave
# Inserting station 3295 at Central Park W & W 96 St
# Inserting station 3296 at E 93 St & 2 Ave
# Inserting station 3297 at 6 St & 7 Ave
# Inserting station 3298 at Warren St & Court St
# Inserting station 3299 at E 98 St & Park Ave
# Inserting station 3300 at Prospect Park West & 8 St
# Inserting station 3301 at Columbus Ave & W 95 St
# Inserting station 3302 at Columbus Ave & W 103 St
# Inserting station 3303 at Butler St & Court St
# Inserting station 3304 at 6 Ave & 9 St
# Inserting station 3305 at E 91 St & 2 Ave
# Inserting station 3306 at 10 St & 7 Ave
# Inserting station 3307 at West End Ave & W 94 St
# Inserting station 3308 at Kane St & Clinton St
# Inserting station 3309 at E 97 St & 3 Ave
# Inserting station 3310 at 14 St & 7 Ave
# Inserting station 3311 at Columbia St & Kane St
# Inserting station 3312 at 1 Ave & E 94 St
# Inserting station 3313 at 6 Ave & 12 St
# Inserting station 3314 at W 95 St & Broadway
# Inserting station 3315 at Henry St & Degraw St
# Inserting station 3317 at 10 St & 5 Ave
# Inserting station 3318 at 2 Ave & E 96 St
# Inserting station 3319 at 14 St & 5 Ave
# Inserting station 3320 at Central Park West & W 100 St
# Inserting station 3321 at Clinton St & Union St
# Inserting station 3322 at 12 St & 4 Ave
# Inserting station 3323 at W 106 St & Central Park West
# Inserting station 3324 at 3 Ave & 14 St
# Inserting station 3326 at Clinton St & Centre St
# Inserting station 3327 at 3 Ave & E 100 St
# Inserting station 3328 at W 100 St & Manhattan Ave
# Inserting station 3329 at Degraw St & Smith St
# Inserting station 3330 at Henry St & Bay St
# Inserting station 3331 at Riverside Dr & W 104 St
# Inserting station 3332 at Degraw St & Hoyt St
# Inserting station 3333 at Columbia St & Lorraine St
# Inserting station 3335 at Union St & 4 Ave
# Inserting station 3336 at E 97 St & Madison Ave
# Inserting station 3337 at Dwight St & Van Dyke St
# Inserting station 3338 at 2 Ave & E 99 St
# Inserting station 3339 at Berkeley Pl & 6 Ave
# Inserting station 3340 at Wolcott St & Dwight St
# Inserting station 3341 at Central Park West & W 102 St
# Inserting station 3342 at Pioneer St & Richards St
# Inserting station 3343 at W 107 St & Columbus Ave
# Inserting station 3344 at Pioneer St & Van Brunt St
# Inserting station 3345 at Madison Ave & E 99 St
# Inserting station 3346 at Berkeley Pl & 7 Ave
# Inserting station 3347 at Van Brunt St & Wolcott St
# Inserting station 3348 at Coffey St & Conover St
# Inserting station 3349 at Grand Army Plaza & Plaza St West
# Inserting station 3350 at W 100 St & Broadway
# Inserting station 3351 at E 102 St & 1 Ave
# Inserting station 3352 at Sigourney St & Columbia St
# Inserting station 3354 at 3 St & Prospect Park West
# Inserting station 3355 at E 66 St & Madison Ave
# Inserting station 3356 at Amsterdam Ave & W 66 St
# Inserting station 3357 at W 106 St & Amsterdam Ave
# Inserting station 3358 at Garfield Pl & 8 Ave
# Inserting station 3359 at E 68 St & Madison Ave
# Inserting station 3360 at Amsterdam Ave & W 79 St
# Inserting station 3361 at Carroll St & 6 Ave
# Inserting station 3362 at Madison Ave & E 82 St
# Inserting station 3363 at E 102 St & Park Ave
# Inserting station 3364 at Carroll St & 5 Ave
# Inserting station 3365 at 3 St & 7 Ave
# Inserting station 3366 at West End Ave & W 107 St
# Inserting station 3367 at 5 Ave & E 103 St
# Inserting station 3368 at 5 Ave & 3 St
# Inserting station 3369 at E 82 St & East End Ave
# Inserting station 3370 at E 78 St & 2 Ave
# Inserting station 3371 at 4 Ave & 2 St
# Inserting station 3372 at E 74 St & 1 Ave
# Inserting station 3373 at 3 St & 3 Ave
# Inserting station 3374 at Central Park North & Adam Clayton Powell Blvd
# Inserting station 3375 at 3 Ave & E 72 St
# Inserting station 3376 at E 65 St & 2 Ave
# Inserting station 3377 at Carroll St & Bond St
# Inserting station 3378 at E 76 St & Park Ave
# Inserting station 3379 at E 103 St & Lexington Ave
# Inserting station 3381 at 3 St & Hoyt St
# Inserting station 3382 at Carroll St & Smith St
# Inserting station 3383 at Cathedral Pkwy & Broadway
# Inserting station 3384 at Smith St & 3 St
# Inserting station 3386 at 1 Pl & Clinton St
# Inserting station 3387 at E 106 St & Madison Ave
# Inserting station 3388 at President St & Henry St
# Inserting station 3389 at Carroll St & Columbia St
# Inserting station 3390 at E 109 St & 3 Ave
# Inserting station 3391 at E 106 St & 1 Ave
# Inserting station 3392 at Commerce St & Van Brunt St
# Inserting station 3393 at Richards St & Delavan St
# Inserting station 3394 at Columbia St & W 9 St
# Inserting station 3396 at Clinton St & 4 Place
# Inserting station 3397 at Court St & Nelson St
# Inserting station 3398 at Smith St & 9 St
# Inserting station 3399 at 7 St & 3 Ave
# Inserting station 3400 at E 110 St & Madison Ave
# Inserting station 3401 at 2 Ave & 9 St
# Inserting station 3402 at Court St & State St
# Inserting station 3403 at 4 Ave & 9 St
# Inserting station 3404 at 7 St & 5 Ave
# Inserting station 3405 at 5 St & 6 Ave
# Inserting station 3407 at Union St & Nevins St
# Inserting station 3408 at Congress St & Clinton St
# Inserting station 3409 at Bergen St & Smith St
# Inserting station 3410 at Dean St & Hoyt St
# Inserting station 3411 at Bond St & Bergen St
# Inserting station 3412 at Pacific St & Nevins St
# Inserting station 3413 at Wyckoff St & 3 Ave
# Inserting station 3414 at Bergen St & Flatbush Ave
# Inserting station 3415 at Prospect Pl & 6 Ave
# Inserting station 3417 at Baltic St & 5 Ave
# Inserting station 3418 at Plaza St West & Flatbush Ave
# Inserting station 3419 at Douglass St & 4 Ave
# Inserting station 3420 at Douglass St & 3 Ave
# Inserting station 3421 at Hoyt St & Warren St
# Inserting station 3422 at Columbia St & Degraw St
# Inserting station 3423 at West Drive & Prospect Park West
# Inserting station 3424 at E 106 St & Lexington Ave
# Inserting station 3425 at 2 Ave & E 104 St
# Inserting station 3427 at Lafayette St & Jersey St
# Inserting station 3429 at Hanson Pl & Ashland Pl
# Inserting station 3430 at Richardson St & N Henry St
# Inserting station 3431 at E 35 St & 3 Ave
# Inserting station 3434 at W 88 St & West End Ave
# Inserting station 3435 at Grand St & Elizabeth St
# Inserting station 3437 at Riverside Dr & W 91 St
# Inserting station 3440 at Fulton St & Adams St
# Inserting station 3449 at Eckford St & Engert Ave
# Inserting station 3452 at Bayard St & Leonard St
# Inserting station 3453 at Devoe St & Lorimer St
# Inserting station 3454 at Leonard St & Maujer St
# Inserting station 3456 at Jackson St & Leonard St
# Inserting station 3457 at E 58 St & Madison Ave
# Inserting station 3458 at W 55 St & 6 Ave
# Inserting station 3459 at E 53 St & 3 Ave
# Inserting station 3461 at Murray St & Greenwich St
# Inserting station 3462 at E 44 St & 2 Ave
# Inserting station 3463 at E 16 St & Irving Pl
# Inserting station 3467 at W Broadway & Spring Street
# Inserting station 3469 at India St & West St
# Inserting station 3472 at W 15 St & 10 Ave
# Inserting station 3474 at 6 Ave & Spring St
# Inserting station 3477 at 39 St & 2 Ave - Citi Bike HQ at Industry City
# Inserting station 3478 at 2 Ave & 36 St - Citi Bike HQ at Industry City
# Inserting station 3481 at York St
# Inserting station 3483 at Montgomery St
# Inserting station 3486 at Schermerhorn St & Bond St
# Inserting station 3489 at Gold St & Frankfort St
# Inserting station 3490 at E 116 St & 2 Ave
# Inserting station 3491 at E 118 St & 1 Ave
# Inserting station 3492 at E 118 St & Park Ave
# Inserting station 3493 at E 118 St & 3 Ave
# Inserting station 3494 at E 115 St & Lexington Ave
# Inserting station 3495 at E 114 St & 1 Ave
# Inserting station 3496 at 1 Ave & E 110 St
# Inserting station 3497 at Pleasant Ave & E 116 St
# Inserting station 3498 at Pleasant Ave & E 120 St
# Inserting station 3499 at 2 Ave & E 122 St
# Inserting station 3500 at E 115 St & Madison Ave
# Inserting station 3501 at E 118 St & Madison Ave
# Inserting station 3502 at Lexington Ave & E 111 St
# Inserting station 3503 at Madison Ave & E 120 St
# Inserting station 3504 at E 123 St & Lexington Ave
# Inserting station 3505 at Lexington Ave & E 127 St
# Inserting station 3506 at Lexington Ave & E 120 St
# Inserting station 3507 at Park Ave & E 124 St
# Inserting station 3508 at St Nicholas Ave & Manhattan Ave
# Inserting station 3509 at Lenox Ave & W 115 St
# Inserting station 3510 at Adam Clayton Powell Blvd & W 123 St
# Inserting station 3511 at Adam Clayton Powell Blvd & W 115 St
# Inserting station 3512 at 27 Ave & 4 St
# Inserting station 3513 at 21 St & Hoyt Ave S
# Inserting station 3514 at Astoria Park S & Shore Blvd
# Inserting station 3515 at 24 Ave & 26 St
# Inserting station 3516 at 31 St & Astoria Blvd
# Inserting station 3517 at 31 St & Hoyt Ave N
# Inserting station 3518 at Lenox Ave & W 126 St
# Inserting station 3519 at 28 Ave & 43 St
# Inserting station 3520 at Adam Clayton Powell Blvd & W 118 St
# Inserting station 3521 at Lenox Ave & W 111 St
# Inserting station 3522 at 37 St & 24 Ave
# Inserting station 3523 at 24 Ave & 29 St
# Inserting station 3524 at 19 St & 24 Ave
# Inserting station 3525 at 23 Ave & 27 St
# Inserting station 3526 at 31 St & 23 Ave
# Inserting station 3527 at 5 Ave & E 126 St
# Inserting station 3528 at Steinway St & 23 Ave
# Inserting station 3529 at Lenox Ave & W 130 St
# Inserting station 3530 at Crescent St & Ditmars Blvd
# Inserting station 3531 at Frederick Douglass Blvd & W 129 St
# Inserting station 3532 at Ditmars Blvd & 19 St
# Inserting station 3533 at St. Nicholas Ave & W 126 St
# Inserting station 3534 at Frederick Douglass Blvd & W 117 St
# Inserting station 3535 at Mt Morris Park W & W 120 St
# Inserting station 3536 at W 116 St & Broadway
# Inserting station 3537 at Carlton Ave & Dean St
# Inserting station 3538 at W 110 St & Amsterdam Ave
# Inserting station 3539 at W 116 St & Amsterdam Ave
# Inserting station 3540 at Morningside Ave & W 123 St
# Inserting station 3541 at Amsterdam Ave & W 125 St
# Inserting station 3542 at Amsterdam Ave & W 119 St
# Inserting station 3543 at Morningside Dr & Amsterdam Ave
# Inserting station 3544 at Underhill Ave & Pacific St
# Inserting station 3545 at Broadway & W 122 St
# Inserting station 3546 at Pacific St & Classon Ave
# Inserting station 3547 at Broadway & Moylan Pl
# Inserting station 3549 at Grand Ave & Bergen St
# Inserting station 3551 at 3 Ave & E 112 St
# Inserting station 3552 at W 113 St & Broadway
# Inserting station 3553 at Frederick Douglass Blvd & W 112 St
# Inserting station 3554 at Vernon Blvd & 41 Rd
# Inserting station 3555 at 28 St & 41 Ave
# Inserting station 3556 at 24 St & 41 Ave
# Inserting station 3557 at 40 Ave & 9 St
# Inserting station 3558 at Bergen St & Vanderbilt Ave
# Inserting station 3559 at 21 St & 38 Ave
# Inserting station 3560 at 28 St & 38 Ave
# Inserting station 3561 at 37 Ave & 35 St
# Inserting station 3562 at Classon Ave & St Marks Ave
# Inserting station 3563 at 28 St & 36 Ave
# Inserting station 3564 at 21 St & 36 Ave
# Inserting station 3565 at 36 Ave & 10 St
# Inserting station 3566 at Crescent St & 35 Ave
# Inserting station 3567 at 11 St & 35 Ave
# Inserting station 3568 at 34 St & 35 Ave
# Inserting station 3569 at Franklin Ave & St Marks Ave
# Inserting station 3570 at 35 Ave & 37 St
# Inserting station 3571 at Bedford Ave & Bergen St
# Inserting station 3572 at 34 Ave & 38 St
# Inserting station 3573 at 35 St & 34 Ave
# Inserting station 3574 at Prospect Pl & Underhill Ave
# Inserting station 3575 at Crescent St & 34 Ave
# Inserting station 3576 at Park Pl & Vanderbilt Ave
# Inserting station 3577 at 34 Ave & 21 St
# Inserting station 3578 at Park Pl & Franklin Ave
# Inserting station 3579 at Sterling Pl & Bedford Ave
# Inserting station 3580 at St Johns Pl & Washington Ave
# Inserting station 3581 at Underhill Ave & Lincoln Pl
# Inserting station 3582 at Lincoln Pl & Classon Ave
# Inserting station 3583 at Eastern Pkwy & Washington Ave
# Inserting station 3584 at Eastern Pkwy & Franklin Ave
# Inserting station 3585 at Union St & Bedford Ave
# Inserting station 3586 at 34 Ave & 13 St
# Inserting station 3587 at Carroll St & Washington Ave
# Inserting station 3588 at Vernon Blvd & 10 St
# Inserting station 3589 at Broadway & 12 St
# Inserting station 3590 at Carroll St & Franklin Ave
# Inserting station 3591 at 21 St & 31 Dr
# Inserting station 3592 at Crescent St & Broadway
# Inserting station 3593 at 31 St & Broadway
# Inserting station 3595 at 35 St & Broadway
# Inserting station 3596 at Sullivan Pl & Bedford Ave
# Inserting station 3597 at 43 St & Broadway
# Inserting station 3598 at Newton Rd & 44 St
# Inserting station 3599 at Franklin Ave & Empire Blvd
# Inserting station 3601 at Sterling St & Bedford Ave
# Inserting station 3602 at 31 Ave & 34 St
# Inserting station 3603 at 31 Ave & 30 St
# Inserting station 3604 at Rogers Ave & Sterling St
# Inserting station 3605 at 31 Ave & Crescent St
# Inserting station 3606 at 49 Ave & 21 St
# Inserting station 3607 at 31 Ave & 14 St
# Inserting station 3664 at North Moore St & Greenwich St
# Inserting station 3608 at 5 St & 51 Ave
# Inserting station 3609 at Vernon Blvd & 31 Ave
# Inserting station 3610 at Vernon Blvd & 30 Rd
# Inserting station 3611 at Vernon Blvd & 47 Rd
# Inserting station 3612 at 30 Ave & 21 St
# Inserting station 3613 at Center Blvd & 48 Ave
# Inserting station 3614 at Crescent St & 30 Ave
# Inserting station 3615 at 44 Dr & 21 St
# Inserting station 3616 at Steinway St & 28 Ave
# Inserting station 3617 at 28 Ave & 35 St
# Inserting station 3618 at 27 St & Hunter St
# Inserting station 3619 at Newtown Ave & 23 St
# Inserting station 3620 at 11 St & 43 Ave
# Inserting station 3621 at 27 Ave & 9 St
# Inserting station 3622 at E 128 St & Madison Ave
# Inserting station 3623 at W 120 St & Claremont Ave
# Inserting station 3628 at Lenox Ave & W 117 St
# Inserting station 3629 at Adam Clayton Powell Blvd & W 126 St
# Inserting station 3630 at Frederick Douglass Blvd & W 115 St
# Inserting station 3631 at Crown St & Bedford Ave
# Inserting station 3632 at E 12 St & Avenue B
# Inserting station 3637 at Fulton St & Waverly Ave
# Inserting station 3638 at Washington St
# Inserting station 3639 at Harborside
# Inserting station 3640 at Journal Square
# Inserting station 3641 at Broadway & W 25 St
# Inserting station 3646 at 35 Ave & 10 St
# Inserting station 3647 at 48 Ave & 30 Pl
# Inserting station 3648 at Flushing Ave & Vanderbilt Ave
# Inserting station 3649 at W 129 St & Convent Ave
# Inserting station 3653 at 31 St & 35 Ave
# Inserting station 3654 at 31 St & Northern Blvd
# Inserting station 3656 at E 2 St & Avenue A
# Inserting station 3658 at W 18 St & 9 Ave
# Inserting station 3659 at W 17 St & 9 Ave
# Inserting station 3660 at W 16 St & 8 Ave
# Inserting station 3661 at Montgomery St & Franklin Ave
# Inserting station 3662 at 31 Ave & Steinway St
# Inserting station 3663 at Sterling Pl & 7 Ave
# Inserting station 3666 at 32 St & 30 Ave
# Inserting station 3668 at Leonard St & Nassau Ave
# Inserting station 3669 at Henry St & W 9 St
# Inserting station 3671 at E 81 St & 2 Ave
# Inserting station 3673 at Dean St & Franklin Ave
# Inserting station 3674 at Jay St & York St
# Inserting station 3675 at 3 Ave & E 95 St
# Inserting station 3676 at Van Brunt St & Van Dyke St
# Inserting station 3677 at Glenwood Ave
# Inserting station 3678 at Fairmount Ave
# Inserting station 3679 at Bergen Ave
# Inserting station 3680 at E 43 St & 5 Ave
# Inserting station 3681 at Grand St
# Inserting station 3684 at W 12 St & W 4 St
# Inserting station 3686 at Gansevoort St & Hudson St
# Inserting station 3687 at E 33 St & 1 Ave
# Inserting station 3689 at W 104 St & Amsterdam Ave
# Inserting station 3690 at Park Pl & Church St
# Inserting station 3691 at 28 Ave & 44 St
# Inserting station 3692 at 5 St & Market St
# Inserting station 3693 at N 11 St & Kent Ave
# Inserting station 3694 at Jackson Square
# Inserting station 3697 at W 64 St & Thelonious Monk Circle
# Inserting station 3699 at W 50 St & 9 Ave
# Inserting station 3701 at Cliff St & Fulton St
# Inserting station 3704 at 47 Ave & Skillman Ave
# Inserting station 3707 at Lexington Ave & E 26 St
# Inserting station 3708 at W 13 St & 5 Ave
# Inserting station 3709 at W 15 St & 6 Ave
# Inserting station 3711 at E 13 St & Avenue A
# Inserting station 3712 at W 35 St & Dyer Ave
# Inserting station 3714 at Division Av & Hooper St
# Inserting station 3715 at Driggs Ave & N 9 St
# Inserting station 3716 at 40 Ave & Crescent St

# %%
#Check if data in the databse
cursor = connection.cursor(pymysql.cursors.DictCursor)
cursor.execute("SELECT * FROM citibike.Docks")
rows = cursor.fetchall()

for row in rows:
    print("Station ID:", row["station_id"])
    print("Station Name:", row["station_name"])
    print("Number of Docks:", row["number_of_docks"])
    print("Available Docks:", row["available_docks"])
    print("Last Communication:", row["date"])
    print("=============================================")
    
cursor.close()

# %% [markdown]
# We can, of course, transform the results back into a DataFrame (see below) or we can use the data directly from the rows object (which is a tuple, containing one dictionary object for each line of the results).

# %%
import pandas as pd

cursor = connection.cursor(pymysql.cursors.DictCursor)
cursor.execute("SELECT * FROM citibike.Docks")
rows = cursor.fetchall()
df_from_sql = pd.DataFrame(list(rows))
df_from_sql
# Out:
#      available_docks                date  number_of_docks  station_id  \
# 0                 35 2018-11-15 16:37:20               39          72
# 1                  9 2018-11-15 16:37:03               33          79
# 2                 16 2018-11-15 16:37:08               27          82
# 3                  0 2018-10-09 09:05:09                0          83
# 4                 11 2018-11-15 16:36:59               19         119
# 5                 18 2018-11-15 16:35:33               19         120
# 6                  5 2018-11-15 16:35:39               31         127
# 7                 13 2018-11-15 16:34:32               30         128
# 8                 13 2018-11-15 16:34:35               24         143
# 9                  1 2018-11-15 16:34:41               19         144
# 10                25 2018-11-15 16:38:06               39         146
# 11                26 2018-11-15 16:37:47               29         150
# 12                 4 2018-11-15 16:34:54               33         151
# 13                18 2018-11-15 16:38:05               23         157
# 14                 7 2018-11-15 16:38:15               35         161
# 15                14 2018-11-15 16:38:09               47         164
# 16                34 2018-11-15 16:36:39               45         167
# 17                 5 2018-11-15 16:38:03               47         168
# 18                18 2018-11-15 16:35:36               51         173
# 19                20 2018-11-15 16:36:53               30         174
# 20                28 2018-11-15 16:37:01               45         195
# 21                 8 2018-11-15 16:36:11               28         212
# 22                18 2018-11-15 16:38:12               23         216
# 23                21 2018-11-15 16:35:56               39         217
# 24                14 2018-11-15 16:36:49               33         223
# 25                 1 2018-11-15 16:35:45               55         228
# 26                 1 2018-11-15 16:37:10               23         229
# 27                16 2018-11-15 16:37:37               23         232
# 28                35 2018-11-15 16:37:14               39         236
# 29                35 2018-11-15 16:35:43               39         237
# ..               ...                 ...              ...         ...
# 784               21 2018-11-15 16:35:00               21        3673
# 785                3 2018-11-15 16:34:59               27        3674
# 786               30 2018-11-15 16:37:37               31        3675
# 787               18 2018-11-15 16:36:47               24        3676
# 788               13 2018-11-15 16:36:35               18        3677
# 789               15 2018-11-15 16:35:01               18        3678
# 790               10 2018-11-15 16:38:26               14        3679
# 791                5 2018-11-15 16:38:10               55        3680
# 792               16 2018-11-15 16:35:03               18        3681
# 793               34 2018-11-15 16:36:04               43        3684
# 794                4 2018-11-15 16:38:20               39        3686
# 795               16 2018-11-15 16:36:41               59        3687
# 796                0 2018-11-02 11:32:24                0        3689
# 797                9 2018-11-15 16:35:52               36        3690
# 798               16 2018-11-15 16:35:43               19        3691
# 799                1 2018-11-15 16:36:42               15        3692
# 800                3 2018-11-15 16:34:57               27        3693
# 801               15 2018-11-15 16:35:11               18        3694
# 802               33 2018-11-15 16:36:48               43        3697
# 803               28 2018-11-15 16:36:18               30        3699
# 804               11 2018-11-15 16:35:42               37        3701
# 805                0 2018-11-15 16:37:17               19        3704
# 806               46 2018-11-15 16:37:12               55        3707
# 807                0 2018-11-15 16:36:37               29        3708
# 808               37 2018-11-15 16:36:42               51        3709
# 809               38 2018-11-15 16:34:43               47        3711
# 810               33 2018-11-15 16:37:14               41        3712
# 811               57 2018-11-15 16:36:40               61        3714
# 812                6 2018-11-15 16:37:34               31        3715
# 813               21 2018-11-15 16:36:58               23        3716
#
#                          station_name
# 0                    W 52 St & 11 Ave
# 1            Franklin St & W Broadway
# 2              St James Pl & Pearl St
# 3       Atlantic Ave & Fort Greene Pl
# 4            Park Ave & St Edwards St
# 5         Lexington Ave & Classon Ave
# 6               Barrow St & Hudson St
# 7            MacDougal St & Prince St
# 8           Clinton St & Joralemon St
# 9                 Nassau St & Navy St
# 10               Hudson St & Reade St
# 11                  E 2 St & Avenue C
# 12           Cleveland Pl & Spring St
# 13            Henry St & Atlantic Ave
# 14              LaGuardia Pl & W 3 St
# 15                    E 47 St & 2 Ave
# 16                    E 39 St & 3 Ave
# 17                    W 18 St & 6 Ave
# 18                 Broadway & W 49 St
# 19                    E 25 St & 1 Ave
# 20              Liberty St & Broadway
# 21            W 16 St & The High Line
# 22    Columbia Heights & Cranberry St
# 23                      Old Fulton St
# 24                    W 13 St & 7 Ave
# 25                    E 48 St & 3 Ave
# 26                     Great Jones St
# 27        Cadman Plaza E & Tillary St
# 28                St Marks Pl & 2 Ave
# 29                    E 11 St & 2 Ave
# ..                                ...
# 784            Dean St & Franklin Ave
# 785                  Jay St & York St
# 786                   3 Ave & E 95 St
# 787        Van Brunt St & Van Dyke St
# 788                      Glenwood Ave
# 789                     Fairmount Ave
# 790                        Bergen Ave
# 791                   E 43 St & 5 Ave
# 792                          Grand St
# 793                  W 12 St & W 4 St
# 794         Gansevoort St & Hudson St
# 795                   E 33 St & 1 Ave
# 796          W 104 St & Amsterdam Ave
# 797               Park Pl & Church St
# 798                    28 Ave & 44 St
# 799                  5 St & Market St
# 800                N 11 St & Kent Ave
# 801                    Jackson Square
# 802  W 64 St & Thelonious Monk Circle
# 803                   W 50 St & 9 Ave
# 804              Cliff St & Fulton St
# 805             47 Ave & Skillman Ave
# 806           Lexington Ave & E 26 St
# 807                   W 13 St & 5 Ave
# 808                   W 15 St & 6 Ave
# 809                E 13 St & Avenue A
# 810                W 35 St & Dyer Ave
# 811           Division Av & Hooper St
# 812               Driggs Ave & N 9 St
# 813              40 Ave & Crescent St
#
# [814 rows x 5 columns]

# %%
# We can then compute functions directly on the dataframe
print(sum(df_from_sql["number_of_docks"]))
print(sum(df_from_sql["available_docks"]))
# Out:
# 24332
# 14153

# %%
# The other way to compute functions directly on the dataframe
print(df_from_sql["number_of_docks"].sum())
print(df_from_sql["available_docks"].sum())
# Out:
# 24332
# 14153

# %%
# And we can also create 
df_from_sql["bikes_taken"] = df_from_sql["number_of_docks"] - df_from_sql["available_docks"]

# %%
df_from_sql.head(5)
# Out:
#    available_docks                date  number_of_docks  station_id  \
# 0               35 2018-11-15 16:37:20               39          72
# 1                9 2018-11-15 16:37:03               33          79
# 2               16 2018-11-15 16:37:08               27          82
# 3                0 2018-10-09 09:05:09                0          83
# 4               11 2018-11-15 16:36:59               19         119
#
#                     station_name  bikes_taken
# 0               W 52 St & 11 Ave            4
# 1       Franklin St & W Broadway           24
# 2         St James Pl & Pearl St           11
# 3  Atlantic Ave & Fort Greene Pl            0
# 4       Park Ave & St Edwards St            8

# %% [markdown]
# Finally, let's close our database connection.

# %%
connection.close()

# %%
#store data into xls and csv formats
df_from_sql.to_excel("citibike.xls")
df_from_sql.to_csv("citibike.csv")

# %% [markdown]
# ## Exercise
#
# Create a new table `'Station'` to store stable information about the station, such as location and street address.

# %%
# Your code is here
cursor = connection.cursor()
db_name = 'citibike'
table_name = 'Station'
# Create a table
# The {0} and {1} are placeholders for the parameters in the format(....) statement
create_table_query = '''CREATE TABLE IF NOT EXISTS {0}.{1} 
                                (station_id int, 
                                station_name varchar(250), 
                                number_of_docks int,
                                address varchar(250),
                                PRIMARY KEY(station_id)
                                )'''.format(db_name, table_name)
cursor.execute(create_table_query)
cursor.close()

# %%
query_template = '''
INSERT INTO 
citibike.Station(station_id, station_name,
                number_of_docks, address) 
        VALUES (%s, %s, %s, %s)'''

cursor = connection.cursor()

for entry in data:
    stationid = entry["id"]
    name = entry["stationName"]
    docks = entry["totalDocks"]
    address = entry["stAddress1"]
    print("Inserting station", stationid, "at", address)
    query_parameters = (stationid, name, docks, address)
    cursor.execute(query_template, query_parameters)

'''
Commit changes to stable storage
'''
connection.commit()
cursor.close()
